# %% [markdown]
# ### Context

# %% [markdown]
# #### **Key Components to Implement**
# 1. **Recurrent Neural Networks (RNNs)**:
#    - Two layers: Sensory layer and M1 layer.
#    - Sensory layer processes proprioceptive feedback.
#    - M1 layer generates descending commands to muscles.
#
# 2. **Spinal Reflex**:
#    - Afferent feedback from muscle kinematics (length, velocity, acceleration, jerk).
#    - Reflex gain applied to the afferent feedback.
#
# 3. **Muscle Activation Dynamics**:
#    - Combines descending commands from M1 and spinal reflex.
#    - Includes time delays for neural and spinal reflex pathways.
#
# 4. **Musculoskeletal Model**:
#    - Two-segment arm with six muscles.
#    - Muscle activations produce forces, which generate joint torques and motion.
#
# 5. **Feedback Loop**:
#    - Joint angles, velocities, and muscle states are fed back to the RNNs and spinal reflex.

# %% [markdown]
# #### **1. Sensory Layer (`y_s`)**
# - **Description**: Represents the sensory cortex, which processes sensory feedback (`u_fb`).
# - **Number of Units**: `n_s = 200` (as per the researchers' description).
# - **Shape**: `[n_s]` or `[200]` (a 1D tensor with 200 elements).
#
# ---
#
# #### **2. Motor Layer (`y_m`)**
# - **Description**: Represents the motor cortex, which generates descending commands to muscles.
# - **Number of Units**: `n_m1 = 200` (as per the researchers' description).
# - **Shape**: `[n_m1]` or `[200]` (a 1D tensor with 200 elements).
#
# ---
#
# #### **3. Muscle Activation Layer (`y_act`)**
# - **Description**: Projects the motor cortex output to the muscles. The number of units matches the number of muscles.
# - **Number of Units**: `n_muscles = 6` (6 muscles in the `myoElbow` model).
# - **Shape**: `[n_muscles]` or `[6]` (a 1D tensor with 6 elements).
#
# ---
#
# #### **4. Feedback Input (`u_fb`)**
# - **Description**: Proprioceptive feedback, including joint angles, velocities, and muscle forces.
# - **Components**:
#   - `θ_d(t)`: Delayed joint angles (e.g., shoulder and elbow).
#   - `θ_g`: Goal joint angles.
#   - `F_m`: Muscle forces (6 muscles).
# - **Shape**: `[n_inputs]` or `[10]` (2 joint angles + 2 joint velocities + 6 muscle forces).
#
# ---
#
# #### **5. Afferent Feedback (`x_aff`)**
# - **Description**: Encodes muscle kinematics (length, velocity, acceleration, jerk) for each muscle.
# - **Components**:
#   - `Δx_ml`: Muscle length changes.
#   - `x_mv`: Muscle velocities.
#   - `x_ma`: Muscle accelerations.
#   - `x_mj`: Muscle jerks.
# - **Shape**: `[n_muscles, 4]` or `[6, 4]` (6 muscles × 4 kinematic states).
#
# ---
#
# #### **6. Weight Matrices**
# - **Sensory Layer Weights (`w_sr`, `w_si`)**:
#   - `w_sr`: Recurrent weights for the sensory layer.
#     - Shape: `[n_s, n_s]` or `[200, 200]`.
#   - `w_si`: Weights connecting sensory feedback to the sensory layer.
#     - Shape: `[n_s, n_inputs]` or `[200, 10]`.
#
# - **Motor Layer Weights (`w_mr`, `w_mi`)**:
#   - `w_mr`: Recurrent weights for the motor layer.
#     - Shape: `[n_m1, n_m1]` or `[200, 200]`.
#   - `w_mi`: Weights connecting the sensory layer to the motor layer.
#     - Shape: `[n_m1, n_s]` or `[200, 200]`.
#
# - **Muscle Activation Weights (`w_act`)**:
#   - Weights connecting the motor layer to the muscle activation layer.
#     - Shape: `[n_muscles, n_m1]` or `[6, 200]`.
#
# ---
#
# #### **7. Bias Terms**
# - **Sensory Layer Bias (`b_s`)**:
#   - Shape: `[n_s]` or `[200]`.
# - **Motor Layer Bias (`b_m`)**:
#   - Shape: `[n_m1]` or `[200]`.
#
# ---
#
# #### **8. Reflex Parameters**
# - **Stretch Reflex Gain (`G_s`)**:
#   - Scalar value (e.g., `0.8` or `1.9`).
# - **Afferent Encoding Gains (`G_aff`)**:
#   - Shape: `[4]` (for length, velocity, acceleration, jerk).
#
# ---
#
# #### **9. Neural Dynamics**
# - **Sensory Layer Dynamics**:
#   - `y_s(t+Δt) = (1-(Δt/τ_n))*y_s(t) + (Δt/τ_n) * tanh(u_s(t))`
#   - Shape of `y_s`: `[n_s]` or `[200]`.
# - **Motor Layer Dynamics**:
#   - `y_m(t+Δt) = (1-(Δt/τ_n))*y_m(t) + (Δt/τ_n) * tanh(u_m(t))`
#   - Shape of `y_m`: `[n_m1]` or `[200]`.
# - **Muscle Activation Dynamics**:
#   - `y_act(t+Δt) = (1-(Δt/τ_m))*y_act(t) + (Δt/τ_m) * ReLU(u_act(t))`
#   - Shape of `y_act`: `[n_muscles]` or `[6]`.
#
# ---
#
# #### **10. Observation (`obs`)**
# - **Description**: The observation returned by the environment.
# - **Components**:
#   - `qpos`: Joint positions (e.g., shoulder and elbow).
#   - `qvel`: Joint velocities.
#   - `act`: Muscle activations.
#   - `pose_err`: Pose error.
# - **Shape**: `[11]` (as per the `myoElbow` environment).
#
# ---
#
# #### **Summary of Shapes**
#
# | Component                  | Shape         | Description                                      |
# |----------------------------|---------------|--------------------------------------------------|
# | `y_s` (Sensory Layer)      | `[200]`       | Sensory cortex output.                          |
# | `y_m` (Motor Layer)        | `[200]`       | Motor cortex output.                            |
# | `y_act` (Muscle Activation)| `[6]`         | Muscle activation output.                       |
# | `u_fb` (Feedback Input)    | `[10]`         | Proprioceptive feedback.                        |
# | `x_aff` (Afferent Feedback)| `[6, 4]`      | Muscle kinematics (length, velocity, etc.).     |
# | `w_sr`                    | `[200, 200]`  | Sensory layer recurrent weights.               |
# | `w_si`                    | `[200, 10]`    | Sensory feedback to sensory layer weights.      |
# | `w_mr`                    | `[200, 200]`  | Motor layer recurrent weights.                 |
# | `w_mi`                    | `[200, 200]`  | Sensory layer to motor layer weights.           |
# | `w_act`                   | `[6, 200]`    | Motor layer to muscle activation weights.       |
# | `b_s` (Sensory Bias)       | `[200]`       | Sensory layer bias.                             |
# | `b_m` (Motor Bias)         | `[200]`       | Motor layer bias.                               |
# | `G_s`                     | `scalar`      | Stretch reflex gain.                            |
# | `G_aff`                   | `[4]`         | Afferent encoding gains.                        |
# | `obs`                     | `[11]`         | Observation from the environment.               |

# %% [markdown]
# ### Imports

# %%
import numpy as np
import torch
import random
import torch.nn as nn
import matplotlib.pyplot as plt
import gymnasium as gym
# Out:
# MyoSuite:> Registering Myo Envs
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# Users of this version of Gym should be able to simply replace 'import gym' with 'import gymnasium as gym' in the vast majority of cases.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# /opt/anaconda3/envs/opensim_scripting/lib/python3.11/site-packages/gymnasium/envs/registration.py:694: UserWarning: WARN: Overriding environment myoArmReachFixed-v0 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")
# /opt/anaconda3/envs/opensim_scripting/lib/python3.11/site-packages/gymnasium/envs/registration.py:694: UserWarning: WARN: Overriding environment myoSarcArmReachFixed-v0 already in registry.
# ...

# %% [markdown]
# ### Constants

# %%
# --- Simulation parameters ---
dt = 0.01       # Time step (10 ms)
tau_n = 0.02    # Neuron time constant (20 ms)
tau_m = 0.05    # Muscle time constant (50 ms)

# --- Neural network parameters ---
n_s = 200       # Number of sensory neurons
n_m1 = 200      # Number of motor neurons
n_muscles = 6   # Number of muscles
n_inputs = 10   # Size of proprioceptive feedback (from myoElbow observation)

# --- Feedback gains ---
G_p = 1.0    # Increase position feedback gain
G_d = 1.0    # Increase velocity feedback gain
G_f = 1.0    # Increase force feedback gain

# --- Reflex parameters ---
G_aff = torch.tensor([1.0, 0.1, 0.01, 0.0001])  # Encoding gains for length, velocity, acceleration, jerk
G_s_low = 0.8                                   # Spinal reflex gain (low reflex gain)
G_s_high = 1.9                                  # Spinal reflex gain (high reflex gain)
reflex_delay = int(0.02 / dt)                   # Spinal reflex delay (20 ms)

# --- Transcortical afferent delay ---
feedback_delay_steps = int(0.04 / dt)         # Transcortical afferent delay (40 ms)

# --- Muscle length ---
L_m = torch.ones(n_muscles, requires_grad=True)

# --- Buffers for delayed feedback ---
joint_angle_buffer = [torch.zeros(2) for _ in range(feedback_delay_steps)]
joint_velocity_buffer = [torch.zeros(2) for _ in range(feedback_delay_steps)]

# --- Movement arm matrix (Mm) ---
M_m = torch.tensor([
    [0.00, 0.00],    # TRIlong (elbow extensor)
    [0.00, 0.00],    # TRIlat (elbow extensor)
    [0.00, 0.00],    # TRImed (elbow extensor)
    [0.00, 0.00],    # BIClong (biarticular biceps)
    [0.00, 0.00],    # BICshort (elbow flexor)
    [0.00, 0.00],    # BRA (brachioradialis)
], dtype=torch.float32)

# --- Penalty coefficients for cost function ---
alpha = 0.0001      # Penalizes neural activity
beta = 0.01       # Penalizes force output
gamma = 0.5      # Penalizes kinematic error

# --- Time parameters for background and perturbation loads ---
Tb = 200 / 1000    # Background load onset (200 ms)
Tp = 1500 / 1000   # Perturbation load onset (1500 ms)
T = 3000 / 1000    # Total motion time (3000 ms)
Tsb = 1000 / 1000  # Steady-state realization of background load (1000 ms)
Tsp = 2500 / 1000  # Steady-state realization of perturbation load (2500 ms)

# --- External loads ---
background_load_low = 0.1    # Low background load (Nm)
background_load_high = 0.55  # High background load (Nm)
perturbation_load = 0.25     # Perturbation load (Nm)

# %% [markdown]
# ### Environment

# %%
from MyoElbowPose2D6M import MyoElbowPose2D6MFixed
from gymnasium.envs.registration import register

if "MyoElbowPose2D6MFixed-v0" not in gym.envs.registry:
    register(id="MyoElbowPose2D6MFixed-v0", entry_point="MyoElbowPose2D6M:MyoElbowPose2D6MFixed")

# Create the custom environment
env = gym.make("MyoElbowPose2D6MFixed-v0")

# %% [markdown]
# ## Neural Limb Controller

# %%
class NeuralLimbController(nn.Module):
    """Neural controller for a two-segment limb model."""

    def __init__(self, n_inputs, n_outputs=n_muscles):
        """Initialize the neural controller."""
        super(NeuralLimbController, self).__init__()
        
        # Sensory layer (input layer)
        self.w_sr = nn.Parameter(torch.empty(n_s, n_s).uniform_(-1/np.sqrt(n_inputs), 1/np.sqrt(n_inputs)))
        self.w_si = nn.Parameter(torch.empty(n_s, n_inputs).uniform_(-1/np.sqrt(n_inputs), 1/np.sqrt(n_inputs)))
        self.b_s = nn.Parameter(torch.full((n_s,), 0.1))

        # M1 layer (output layer)
        self.w_mr = nn.Parameter(torch.empty(n_m1, n_m1).uniform_(-1/np.sqrt(n_s), 1/np.sqrt(n_s)))
        self.w_mi = nn.Parameter(torch.empty(n_m1, n_s).uniform_(-1/np.sqrt(n_s), 1/np.sqrt(n_s)))
        self.b_m = nn.Parameter(torch.full((n_m1,), 0.1))
        
        # Muscle activation layer weights (from M1 to muscle)
        self.w_act = nn.Parameter(torch.empty(n_muscles, n_m1).uniform_(-1/np.sqrt(n_m1), 1/np.sqrt(n_m1)))
        
        # Internal state variables
        self.y_s = torch.randn(n_s) * 0.01          # Sensory Layer output (y_s(t))
        self.y_m = torch.randn(n_m1) * 0.01         # M1 Layer output (y_m(t))
        self.y_act = torch.randn(n_muscles) * 0.01  # Muscle Activation output (y_act(t))
    
    def reset_states(self):
        """Reset the internal states of the controller."""
        self.y_s = torch.zeros_like(self.y_s)       # Reset sensory layer state
        self.y_m = torch.zeros_like(self.y_m)       # Reset M1 layer state
        self.y_act = torch.zeros_like(self.y_act)   # Reset muscle activation state

    def neural_activation_step(self, y_t, u_t):
        """Discretized neural activation dynamics."""
        return (1 - (dt / tau_n)) * y_t + (dt / tau_n) * torch.tanh(u_t)
    
    def muscle_activation_step(self, y_act_t, u_act_t):
        """Discretized muscle activation dynamics."""
        return (1 - (dt / tau_m)) * y_act_t + (dt / tau_m) * torch.relu(u_act_t)

    def forward_step(self, u_fb_t, x_aff_t, y_s_delayed_t, G_s):
        """Perform a single forward step of the neural controller."""
        # Sensory layer input (u_s) and output (y_s)
        u_s = self.w_sr @ y_s_delayed_t + self.w_si @ u_fb_t + self.b_s
        self.y_s = self.neural_activation_step(self.y_s, u_s)
        
        # M1 layer input (u_m) and output (y_m)
        u_m = self.w_mr @ self.y_m + self.w_mi @ self.y_s + self.b_m
        self.y_m = self.neural_activation_step(self.y_m, u_m)
        
        # Muscle activation layer input (u_act) and output (y_act)
        u_act = self.w_act @ self.y_m + G_s * x_aff_t
        self.y_act = self.muscle_activation_step(self.y_act, u_act)

        return self.y_act

# %% [markdown]
# ### Hill-type muscle model equations

# %%
class MuscleConstants:
    """Class to store physiologically based constants for muscle dynamics."""
    F_MAX = 1.0               # Maximum isometric force (used for normalization)
    L_OPT = 1.0               # Optimal fiber length (used for normalization)
    V_MAX = 10.0              # Maximum shortening velocity (V_max / L_opt)

    # Coefficients for Shortening
    A_HILL = 0.25             # Normalized coefficient 'a/F_max'
    B_HILL = A_HILL * V_MAX   # Normalized coefficient 'b/L_opt'

    # Coefficients for Lengthening
    K_ECC = 0.15              # Shape factor for the eccentric regime
    F_MAX_ECC = 1.4           # Max force during lengthening (1.4 * F_max)


class ForceLength:
    """Class to compute the force-length relationship for muscles."""
    @staticmethod
    def compute(L_m, L_opt=MuscleConstants.L_OPT, width_factor=0.4):
        """
        Args:
            L_m (torch.Tensor): Normalized muscle length.
            L_opt (float): Optimal fiber length (default: 1.0).
            width_factor (float): Controls the width of the bell curve (default: 0.4).

        Returns:
            torch.Tensor: Force-Length scaling factor (FL).
        """
        exp = -((L_m - L_opt) / width_factor).pow(2)
        return torch.exp(exp)


class ForceVelocity:
    """Class to compute the force-velocity relationship for muscles."""
    @staticmethod
    def compute(dLm_dt, V_max=MuscleConstants.V_MAX, A_hill=MuscleConstants.A_HILL, 
                B_hill=MuscleConstants.B_HILL, F_max_ecc=MuscleConstants.F_MAX_ECC, 
                K_ecc=MuscleConstants.K_ECC):
        """
        Args:
            dLm_dt (torch.Tensor): Normalized muscle velocity (positive for lengthening, negative for shortening).
            V_max (float): Maximum shortening velocity.
            A_hill (float): Hill's coefficient 'a/F_max'.
            B_hill (float): Hill's coefficient 'b/L_opt'.
            F_max_ecc (float): Max force during lengthening.
            K_ecc (float): Shape factor for the eccentric regime.

        Returns:
            torch.Tensor: Force-Velocity scaling factor (FV).
        """
        # Shortening (dLm_dt <= 0): Hill's hyperbolic equation
        FV_shortening = (B_hill - dLm_dt) / (B_hill + A_hill * dLm_dt)
        # Lengthening (dLm_dt > 0): Exponential plateau
        FV_lengthening = (F_max_ecc - 1.0) * (1.0 - torch.exp(-K_ecc * dLm_dt)) + 1.0
        # Combine shortening and lengthening regimes
        return torch.where(dLm_dt <= 0.0, FV_shortening, FV_lengthening)

# %% [markdown]
# ### Cost functions

# %%
def compute_costs(controller, qpos, qvel, F_m, J_b_1_accumulated, J_b_2_accumulated, J_p_accumulated):
    """Compute the neural, force, and kinematic costs."""
    # Neural cost (Instantaneous mean of squared activity)
    neural_cost = controller.y_s.pow(2).mean() + controller.y_m.pow(2).mean()

    # Force output cost (Instantaneous mean of squared force)
    force_cost = F_m.pow(2).mean()

    # Kinematic cost (Final Time-Averaged Costs)
    J_b_1_duration = Tb
    J_b_2_duration = Tp - Tsb
    J_p_duration = T - Tsp

    # Time-Averaged Cost = Integral / Duration
    J_b_1_final = J_b_1_accumulated / J_b_1_duration
    J_b_2_final = J_b_2_accumulated / J_b_2_duration
    J_p_final = J_p_accumulated / J_p_duration
    
    # J_b is the sum of its two components
    J_b_final = J_b_1_final + J_b_2_final
    
    # Total Kinematic Cost
    kinematic_cost = J_b_final + J_p_final

    return neural_cost, force_cost, kinematic_cost, J_b_final, J_p_final

def compute_weighted_costs(neural_cost, force_cost, kinematic_cost, J_b_final, J_p_final, alpha, beta, gamma):
    """Compute weighted components of the cost."""
    return {
        "neural": alpha * neural_cost,
        "force": beta * force_cost,
        "J_b": gamma * J_b_final,
        "J_p": gamma * J_p_final,
        "kinematic": gamma * kinematic_cost,
        "total": alpha * neural_cost + beta * force_cost + gamma * kinematic_cost,
    }

def compute_and_accumulate_costs(controller, qpos, qvel, F_m, J_b_1_accumulated, J_b_2_accumulated, J_p_accumulated, total_costs):
    """Compute costs, apply weights, and accumulate them into total_costs."""
    # Compute costs
    neural_cost, force_cost, kinematic_cost, J_b_final, J_p_final = compute_costs(controller, qpos, qvel, F_m, J_b_1_accumulated, J_b_2_accumulated, J_p_accumulated)
    weighted_costs = compute_weighted_costs(neural_cost, force_cost, kinematic_cost, J_b_final, J_p_final, alpha, beta, gamma)

    # Add L2 regularization to the total cost
    total_cost = weighted_costs["total"]
    l2_reg = 0.01 * sum(p.pow(2).sum() for p in controller.parameters())
    total_cost += l2_reg

    # Accumulate costs
    for key in total_costs:
            if key == "J_b":
                total_costs[key] += weighted_costs[key].item() 
            elif key == "J_p":
                total_costs[key] += weighted_costs[key].item()
            elif key == "neural" or key == "force":
                total_costs[key] += weighted_costs[key].item()
            elif key == "kinematic":
                total_costs[key] += weighted_costs[key].item()
            elif key == "total":
                total_costs[key] += weighted_costs[key].item()

    return total_cost

# %% [markdown]
# ## Training Loop

# %%
# ------- CONSTANTS ---------

# Define the initial position directly
initial_qpos = torch.tensor([0.0, 0.0], dtype=torch.float32)

# Perturbation directions (unit vectors for 8 directions)
perturbation_directions = [
    torch.tensor([1.0, 0.0]),       # Right
    torch.tensor([-1.0, 0.0]),      # Left
    torch.tensor([0.0, 1.0]),       # Up
    torch.tensor([0.0, -1.0]),      # Down
    torch.tensor([0.707, 0.707]),   # Up-Right
    torch.tensor([-0.707, 0.707]),  # Up-Left
    torch.tensor([-0.707, -0.707]), # Down-Left
    torch.tensor([0.707, -0.707])   # Down-Right
]

# Time parameters for external loads (in steps)
background_onset_step = int(Tb / dt)   # 200ms -> 20 steps
perturbation_onset_step = int(Tp / dt) # 1500ms -> 150 steps
perturbation_off_step = int(Tsp / dt)  # 2500ms -> 250 steps
total_steps = int(T / dt)              # 3000ms -> 300 steps

# Time step constants for accumulation logic
Tb_step = int(Tb / dt)      # 20 steps
Tsb_step = int(Tsb / dt)    # 100 steps
Tp_step = int(Tp / dt)      # 150 steps
Tsp_step = int(Tsp / dt)    # 250 steps
T_step = int(T / dt)        # 300 steps

# %%
# ------- NEURAL CONTROLLER AND OPTIMIZER SETUP ---------

# Instantiate the neural controller
controller = NeuralLimbController(n_inputs=n_inputs, n_outputs=n_muscles)

# Set up optimizer
optimizer = torch.optim.Adam(controller.parameters(), lr=0.001, weight_decay=1e-4)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=50, gamma=0.5)

# Initialize dictionaries to store results by target
target_results = {
    i: {
        "pose_errors": [],
        "rewards": [],
        "costs": {"neural": [], "force": [], "kinematic": [], "J_b": [], "J_p": [], "total": []},
        "spinal_contrib": [], "cortical_contrib": [], "muscle_activations": [],
        "reflex_gain": [], "cortical_activity": [], "sensory_activity": [], "motor_activity": []
    }
    for i in range(len(perturbation_directions))
}

# %%
# ------- TRAINING LOOP SETUP ---------

# Training loop
num_epochs = 1

for epoch in range(num_epochs):
    # Reset controller states
    controller.reset_states()

    # Ensure initial and target positions match
    initial_qpos = torch.tensor([0.0, 0.0], dtype=torch.float32)
    target_qpos = initial_qpos.clone()

    # Randomly select background load condition
    background_load = background_load_high if random.random() > 0.5 else background_load_low
    G_s = G_s_high if background_load == background_load_high else G_s_low

    # Select a random perturbation direction
    perturbation_idx = random.randint(0, len(perturbation_directions) - 1)
    perturbation_dir = perturbation_directions[perturbation_idx]

    # Reset the environment to the initial position
    obs, info = env.reset(initial_qpos=initial_qpos.numpy())
    terminated, truncated = False, False
    total_costs = {key: 0 for key in ["neural", "force", "kinematic", "J_b", "J_p", "total"]}
    step_count = 0

    # Initialize kinematic cost accumulators
    J_b_1_accumulated = torch.tensor(0.0, requires_grad=True) # Integral from 0 to T_b
    J_b_2_accumulated = torch.tensor(0.0, requires_grad=True) # Integral from T_sb to T_p
    J_p_accumulated = torch.tensor(0.0, requires_grad=True)   # Integral from T_sp to T

    # Initialize lists to store positions for visualization
    shoulder_positions = []
    elbow_positions = []

    # Initialize lists to store pose errors and rewards for this epoch
    pose_errors, rewards = [], []
    spinal_contrib_epoch, cortical_contrib_epoch = [], []
    muscle_activations_epoch = []
    reflex_gain_epoch, cortical_activity_epoch = [], []

    # Initialize muscle kinematics buffers
    L_m = torch.tensor([1.05, 1.02, 1.00, 0.98, 0.97, 0.99], requires_grad=True)
    L_m_initial = L_m.clone().detach()

    delta_L_m = torch.zeros(n_muscles)
    velocity_L_m = torch.zeros(n_muscles)
    acceleration_L_m = torch.zeros(n_muscles)
    jerk_L_m = torch.zeros(n_muscles)


    # ------- TRAINING LOOP EXECUTION ---------

    while not (terminated or truncated):    
        # Detach internal states
        for state in [controller.y_s, controller.y_m, controller.y_act]:
            state.detach_()

        # Compute external torque
        background_torque = perturbation_dir * background_load
        external_torque = background_torque.clone()
        if perturbation_onset_step <= step_count < perturbation_off_step:
            external_torque += perturbation_dir * perturbation_load
        env.unwrapped.set_external_torque(external_torque.detach().numpy())

        # Extract observation components
        shoulder_pos = torch.tensor(obs[0], dtype=torch.float32, requires_grad=True)
        shoulder_vel = torch.tensor(obs[1], dtype=torch.float32, requires_grad=True)
        elbow_pos = torch.tensor(obs[2], dtype=torch.float32, requires_grad=True)
        elbow_vel = torch.tensor(obs[3], dtype=torch.float32, requires_grad=True)
        muscle_activations = torch.tensor(obs[4:10], dtype=torch.float32, requires_grad=True)
        pose_error = torch.tensor(obs[10], dtype=torch.float32, requires_grad=True)

        # Combine joint positions and velocities into tensors
        qpos = torch.stack([shoulder_pos, elbow_pos])
        qvel = torch.stack([shoulder_vel, elbow_vel])

        # Track positions for visualization
        shoulder_positions.append(shoulder_pos.item())
        elbow_positions.append(elbow_pos.item())

        # Kinematic accumulation logic
        kinematic_loss_term = (qpos - target_qpos).pow(2).mean() + 0.5 * qvel.pow(2).mean()
        kinematic_loss_integral = kinematic_loss_term * dt

        # Accumulate kinematic costs
        if step_count < Tb_step:
            with torch.no_grad():
                J_b_1_accumulated += kinematic_loss_integral.detach()
        if Tsb_step <= step_count < Tp_step:
            with torch.no_grad():
                J_b_2_accumulated += kinematic_loss_integral.detach()
        if Tsp_step <= step_count < total_steps:
            with torch.no_grad():
                J_p_accumulated += kinematic_loss_integral.detach()

        # Compute muscle length changes
        dLm_dt = (-M_m @ qvel.unsqueeze(1)).squeeze()
        new_L_m = L_m + dLm_dt * dt
        new_L_m, dLm_dt = new_L_m.detach(), dLm_dt.detach()

        # Update muscle kinematics
        new_delta_L_m = new_L_m - L_m_initial
        new_velocity_L_m = dLm_dt
        new_acceleration_L_m = (new_velocity_L_m - velocity_L_m) / dt
        new_jerk_L_m = (new_acceleration_L_m - acceleration_L_m) / dt

        # Update for next step
        L_m = new_L_m
        delta_L_m = new_delta_L_m
        velocity_L_m = new_velocity_L_m
        acceleration_L_m = new_acceleration_L_m
        jerk_L_m = new_jerk_L_m

        # Stack muscle kinematics into a tensor
        x_m = torch.stack([delta_L_m, velocity_L_m, acceleration_L_m, jerk_L_m], dim=1)

        # Compute afferent feedback (spinal contribution)
        x_aff_t = G_aff @ x_m.T
        spinal_contrib_epoch.append(x_aff_t.detach().numpy())

        # Compute reflex gain (norm of spinal contribution)
        reflex_gain = torch.norm(x_aff_t).item()
        reflex_gain_epoch.append(reflex_gain)

        # Compute muscle forces (F_m) using FL and FV properties
        FL = ForceLength.compute(L_m)
        FV = ForceVelocity.compute(dLm_dt.squeeze())
        F_m = muscle_activations * FL * FV

        # Compute feedback input (u_fb)
        position_error = G_p * (qpos - target_qpos)
        velocity_feedback = G_d * qvel
        if step_count % 10 == 0:
            print(f"Step {step_count}: Position Error: {position_error}, Velocity Feedback: {velocity_feedback}\n")
        force_feedback = G_f * F_m
        u_fb = torch.cat([position_error, velocity_feedback, force_feedback], dim=0)

        # Generate muscle activations using the neural controller
        u_fb_t = u_fb
        muscle_activations = controller.forward_step(u_fb_t=u_fb_t, x_aff_t=x_aff_t, y_s_delayed_t=controller.y_s, G_s=G_s)

        # Step the environment
        obs, reward, terminated, truncated, info = env.step(muscle_activations.detach().numpy())
        step_count += 1
            
        if (muscle_activations > 1.0).any():
            print(f"Muscle activation saturation detected at Step {step_count}: {muscle_activations}")

        # Compute and accumulate costs
        total_cost = compute_and_accumulate_costs(controller, qpos, qvel, F_m, J_b_1_accumulated, J_b_2_accumulated, J_p_accumulated, total_costs)

        # Debug print every 30 time steps
        if step_count % 30 == 0:
            print(f"Step {step_count}: Pose Error: {pose_error.item()}")
        #     neural_cost, force_cost, kinematic_cost, J_b, J_p = compute_costs(controller, qpos, qvel, F_m, J_b_1_accumulated, J_b_2_accumulated, J_p_accumulated)
        #     weighted_costs = compute_weighted_costs(neural_cost, force_cost, kinematic_cost, J_b, J_p, alpha, beta, gamma)
        #     print(f"Epoch {epoch + 1}, Step {step_count} | Neural Cost: {weighted_costs['neural']:.4f} | Force Cost: {weighted_costs['force']:.4f} | Kinematic Cost: {weighted_costs['kinematic']:.4f} | J_b: {weighted_costs['J_b']:.4f} | J_p: {weighted_costs['J_p']:.4f} | Total Cost: {weighted_costs['total']:.4f}")

        # Backpropagation
        optimizer.zero_grad()
        total_cost.backward()
        torch.nn.utils.clip_grad_norm_(controller.parameters(), max_norm=1.0)
        optimizer.step()

        # Track pose error and reward for this step
        pose_errors.append(pose_error.item())
        rewards.append(reward)
        muscle_activations_epoch.append(muscle_activations.detach().numpy())

    
    # ------- POST-EPOCH PROCESSING ---------

    # Store pose errors and rewards for this epoch
    target_results[perturbation_idx]["pose_errors"].append(pose_errors)
    target_results[perturbation_idx]["rewards"].append(rewards)
    target_results[perturbation_idx]["spinal_contrib"].append(spinal_contrib_epoch)
    target_results[perturbation_idx]["cortical_contrib"].append(cortical_contrib_epoch)
    target_results[perturbation_idx]["muscle_activations"].append(muscle_activations_epoch)

    # Wrap reflex_gain_epoch and cortical_activity_epoch in lists before appending
    target_results[perturbation_idx]["reflex_gain"].append(list(reflex_gain_epoch))
    target_results[perturbation_idx]["cortical_activity"].append(list(cortical_activity_epoch))

    # Recalculate final costs using the last accumulated tensors for accurate epoch reporting
    final_neural_cost = total_costs['neural'] / total_steps
    final_force_cost = total_costs['force'] / total_steps
    
    final_J_b_1 = J_b_1_accumulated / (Tb)
    final_J_b_2 = J_b_2_accumulated / (Tp - Tsb)
    final_J_b = final_J_b_1 + final_J_b_2
    final_J_p = J_p_accumulated / (T - Tsp)
    final_kinematic_cost = final_J_b + final_J_p
    
    weighted_avg_costs = compute_weighted_costs(
        final_neural_cost, 
        final_force_cost, 
        final_kinematic_cost,
        final_J_b, 
        final_J_p, 
        alpha, beta, gamma
    )
    
    # Store weighted average costs for the epoch
    for key in weighted_avg_costs:
        target_results[perturbation_idx]["costs"][key].append(weighted_avg_costs[key])

    # Step the learning rate scheduler
    scheduler.step()
# Out:
# Step 0: Position Error: tensor([0., 0.], grad_fn=<MulBackward0>), Velocity Feedback: tensor([0., 0.], grad_fn=<MulBackward0>)
#
# Step 10: Position Error: tensor([0.0110, 0.0294], grad_fn=<MulBackward0>), Velocity Feedback: tensor([0.1727, 0.4605], grad_fn=<MulBackward0>)
#
# Step 20: Position Error: tensor([0.0319, 0.0850], grad_fn=<MulBackward0>), Velocity Feedback: tensor([0.2282, 0.6078], grad_fn=<MulBackward0>)
#
# Step 30: Pose Error: 1.5329341888427734
# Step 30: Position Error: tensor([0.0557, 0.1482], grad_fn=<MulBackward0>), Velocity Feedback: tensor([0.2419, 0.6418], grad_fn=<MulBackward0>)
#
# Step 40: Position Error: tensor([0.0798, 0.2121], grad_fn=<MulBackward0>), Velocity Feedback: tensor([0.2394, 0.6348], grad_fn=<MulBackward0>)
#
# Step 50: Position Error: tensor([0.1033, 0.2745], grad_fn=<MulBackward0>), Velocity Feedback: tensor([0.2311, 0.6137], grad_fn=<MulBackward0>)
#
# Step 60: Pose Error: 1.333238124847412
# ...

# %% [markdown]
# ## Plots

# %% [markdown]
# ### Plot functions

# %%
from matplotlib import colormaps

def pad_and_compute_mean_std(data, max_length):
    """Pad data with NaN to the maximum length and compute mean and standard deviation."""
    padded_data = np.array([np.pad(epoch, (0, max_length - len(epoch)), constant_values=np.nan) for epoch in data])
    mean = np.nanmean(padded_data, axis=0)
    std = np.nanstd(padded_data, axis=0)
    return mean, std

def plot_mean_and_std(ax, x, mean, std, label, color, alpha=0.1):
    """Plot mean and standard deviation as a shaded region."""
    ax.plot(x, mean, label=label, color=color)
    ax.fill_between(x, mean - std, mean + std, color=color, alpha=alpha)

def plot_pose_error(ax, perturbation_results):
    """Plot pose error over time for all perturbations."""
    # Define perturbation direction names
    perturbation_names = ["Right", "Left", "Up", "Down", "Up-Right", "Up-Left", "Down-Left", "Down-Right"]
    num_perturbations = len(perturbation_results)
    colormap = colormaps["tab10"].resampled(num_perturbations)

    for perturbation_idx, perturbation_data in perturbation_results.items():
        pose_errors = perturbation_data["pose_errors"]
        if not pose_errors: 
            continue

        max_length = max(len(epoch) for epoch in pose_errors)
        mean, std = pad_and_compute_mean_std(pose_errors, max_length)
        color = colormap(perturbation_idx / num_perturbations)
        plot_mean_and_std(ax, range(len(mean)), mean, std, label=perturbation_names[perturbation_idx], color=color)
    
    ax.set_title("Pose error over time")
    ax.set_xlabel("Time steps")
    ax.set_ylabel("Pose error")
    ax.legend(title="Perturbations")
    ax.grid()

def plot_reward(ax, perturbation_results):
    """Plot reward over time for all perturbations."""
    # Define perturbation direction names
    perturbation_names = ["Right", "Left", "Up", "Down", "Up-Right", "Up-Left", "Down-Left", "Down-Right"]
    num_perturbations = len(perturbation_results)
    colormap = colormaps["tab10"].resampled(num_perturbations)

    for perturbation_idx, perturbation_data in perturbation_results.items():
        rewards = perturbation_data["rewards"]
        if not rewards:
            continue

        max_length = max(len(epoch) for epoch in rewards)
        mean, std = pad_and_compute_mean_std(rewards, max_length)
        color = colormap(perturbation_idx / num_perturbations)
        plot_mean_and_std(ax, range(len(mean)), mean, std, label=perturbation_names[perturbation_idx], color=color)
    
    ax.set_title("Reward over time")
    ax.set_xlabel("Time steps")
    ax.set_ylabel("Reward")
    ax.legend(title="Perturbations")
    ax.grid()

def plot_costs(ax, target_results):
    """Plot costs over epochs without aggregating across perturbation directions."""
    cost_keys = ["neural", "force", "J_b", "J_p", "total"]

    # Initialize arrays to store costs for all epochs
    costs = {key: [] for key in cost_keys}

    # Collect costs for all epochs
    for target_idx, target_data in target_results.items():
        for key in cost_keys:
            # Detach tensors before appending
            costs[key].extend(
                [value.detach().item() if isinstance(value, torch.Tensor) else value for value in target_data["costs"][key]]
            )

    # Convert costs to NumPy arrays
    costs = {key: np.array(values) for key, values in costs.items()}

    # Plot each cost component
    ax.plot(range(1, len(costs["neural"]) + 1), costs["neural"], label="Neural component", color="orange")
    ax.plot(range(1, len(costs["force"]) + 1), costs["force"], label="Force component", linestyle="--", color="cyan")
    ax.plot(range(1, len(costs["J_b"]) + 1), costs["J_b"], label="Kinematic (Jb)", color="blue")
    ax.plot(range(1, len(costs["J_p"]) + 1), costs["J_p"], label="Kinematic (Jp)", color="green")
    ax.plot(range(1, len(costs["total"]) + 1), costs["total"], label="Total cost", color="red")
    ax.set_title("Cost components over epochs")
    ax.set_xlabel("Epochs")
    ax.set_ylabel("Cost")
    ax.legend()
    ax.grid()

def pad_deeply_nested_sequences(data, pad_value=np.nan):
    """
    Flatten and pad a deeply nested list of lists to the same length.

    Args:
        data (list of lists of lists): Deeply nested data to pad.
        pad_value (float): Value to use for padding.

    Returns:
        np.ndarray: Padded 2D array.
    """
    # Ensure all elements are lists
    data = [seq if isinstance(seq, list) else [seq] for seq in data]

    # Flatten the nested structure (combine all epochs into one list of time steps)
    flattened_data = [time_step for epoch in data for time_step in epoch]

    # Find the maximum length of the time steps
    max_length = max(len(seq) for seq in flattened_data)

    # Pad each time step to the maximum length
    padded_data = np.array([
        np.pad(seq, (0, max_length - len(seq)), constant_values=pad_value)
        for seq in flattened_data
    ])
    return padded_data

def pad_variable_length_sequences(data, pad_value=np.nan):
    """
    Pad a list of lists to the same length with a specified pad value.

    Args:
        data (list of lists): Data to pad.
        pad_value (float): Value to use for padding.

    Returns:
        np.ndarray: Padded 2D array.
    """
    # Find the maximum length of the inner lists
    max_length = max(len(seq) for seq in data)

    # Pad each inner list to the maximum length
    padded_data = np.array([
        np.pad(seq, (0, max_length - len(seq)), constant_values=pad_value)
        for seq in data
    ])
    return padded_data

# %% [markdown]
# ### Results

# %%
fig, axes = plt.subplots(1, 3, figsize=(16, 4))  # Create one row with three plots

plot_pose_error(axes[0], target_results)
plot_reward(axes[1], target_results)
plot_costs(axes[2], target_results)
plt.tight_layout()
plt.show()

# %% [markdown]
# ---

# %%
def plot_feedback_contributions_all_muscles(target_results):
    """Plot spinal reflex vs. cortical feedback contributions for all 6 muscles in a 2x3 grid."""
    fig, axes = plt.subplots(2, 3, figsize=(16, 8))  # Create a 2x3 grid of subplots
    axes = axes.flatten()  # Flatten the 2D array of axes for easier indexing

    # Aggregate contributions across all targets
    spinal_contrib_all = []
    cortical_contrib_all = []
    total_activation_all = []

    for target_idx, target_data in target_results.items():
        spinal_contrib_all.extend(target_data["spinal_contrib"])
        cortical_contrib_all.extend(target_data["cortical_contrib"])
        total_activation_all.extend(target_data["muscle_activations"])

    # Pad the sequences to handle variable lengths
    spinal_contrib = pad_deeply_nested_sequences(spinal_contrib_all)
    cortical_contrib = pad_deeply_nested_sequences(cortical_contrib_all)
    total_activation = pad_deeply_nested_sequences(total_activation_all)

    # Plot contributions for each muscle
    for muscle_idx in range(6):  # 6 muscles
        ax = axes[muscle_idx]

        # Extract the contributions for the current muscle
        spinal_contrib_muscle = spinal_contrib[:, muscle_idx]
        cortical_contrib_muscle = cortical_contrib[:, muscle_idx]
        total_activation_muscle = total_activation[:, muscle_idx]

        time_steps = range(spinal_contrib_muscle.shape[0])

        # Plot the contributions
        ax.plot(time_steps, spinal_contrib_muscle, label="Spinal", alpha=0.7)
        ax.plot(time_steps, cortical_contrib_muscle, label="Cortical", alpha=0.7)
        ax.plot(time_steps, total_activation_muscle, label="Total", linestyle="--", alpha=0.7)

        ax.set_title(f"Muscle {muscle_idx + 1}")
        ax.set_xlabel("Time steps")
        ax.set_ylabel("Activation")
        ax.legend()
        ax.grid()

    plt.tight_layout()
    plt.show()

# plot_feedback_contributions_all_muscles(target_results)

# %% [markdown]
# ---

# %%
def plot_reflex_vs_cortical_activity(target_results):
    """Plot reflex gain vs. cortical activity over time."""
    fig, ax = plt.subplots(figsize=(8, 4))

    for target_idx, target_data in target_results.items():
        # Skip if reflex_gain or cortical_activity is empty
        if not target_data["reflex_gain"] or not target_data["cortical_activity"]:
            print(f"Skipping target {target_idx + 1} due to empty data.")
            continue

        # Pad reflex_gain and cortical_activity to handle variable lengths
        reflex_gain = pad_variable_length_sequences(target_data["reflex_gain"])
        cortical_activity = pad_variable_length_sequences(target_data["cortical_activity"])

        # Compute the mean across epochs for each time step
        reflex_gain_mean = np.nanmean(reflex_gain, axis=0)
        cortical_activity_mean = np.nanmean(cortical_activity, axis=0)

        time_steps = range(len(reflex_gain_mean))

        # Plot reflex gain and cortical activity
        ax.plot(time_steps, reflex_gain_mean, label=f"Reflex Gain (Target {target_idx + 1})", alpha=0.7)
        ax.plot(time_steps, cortical_activity_mean, label=f"Cortical Activity (Target {target_idx + 1})", alpha=0.7)

    ax.set_title("Reflex Gain vs. Cortical Activity")
    ax.set_xlabel("Time steps")
    ax.set_ylabel("Value")
    ax.legend()
    ax.grid()
    plt.tight_layout()
    plt.show()

# plot_reflex_vs_cortical_activity(target_results)

# %% [markdown]
# ---

# %%
def plot_muscle_activations(target_results, target_idx=0):
    """
    Plot muscle activations over time for a specific target.

    Args:
        target_results (dict): Dictionary containing results for all targets.
        target_idx (int): Index of the target to plot.
    """
    # Extract muscle activations for the specified target
    muscle_activations = target_results[target_idx]["muscle_activations"]
    if not muscle_activations:
        print(f"No muscle activations data available for target {target_idx}.")
        return

    # Flatten and pad the muscle activations data
    padded_activations = pad_deeply_nested_sequences(muscle_activations)

    # Debugging: Check the shape of padded_activations
    print("Shape of padded_activations:", padded_activations.shape)

    # Compute the mean and standard deviation across epochs
    mean_activations = np.nanmean(padded_activations, axis=0)
    std_activations = np.nanstd(padded_activations, axis=0)

    # Ensure mean_activations is 2D (time steps × muscles)
    if mean_activations.ndim == 1:
        mean_activations = mean_activations[:, np.newaxis]
        std_activations = std_activations[:, np.newaxis]

    # Plot muscle activations for each muscle
    num_muscles = mean_activations.shape[1]
    time_steps = range(mean_activations.shape[0])  # Use the first dimension for time steps

    fig, ax = plt.subplots(figsize=(10, 6))
    for muscle_idx in range(num_muscles):
        ax.plot(
            time_steps,
            mean_activations[:, muscle_idx],
            label=f"Muscle {muscle_idx + 1}"
        )
        ax.fill_between(
            time_steps,
            mean_activations[:, muscle_idx] - std_activations[:, muscle_idx],
            mean_activations[:, muscle_idx] + std_activations[:, muscle_idx],
            alpha=0.2
        )

    ax.set_title(f"Muscle Activations Over Time (Target {target_idx + 1})")
    ax.set_xlabel("Time Steps")
    ax.set_ylabel("Activation")
    ax.legend(title="Muscles")
    ax.grid()
    plt.show()

# plot_muscle_activations(target_results, target_idx=2)

# %% [markdown]
# ---

# %%
def plot_neural_dynamics(target_results, target_idx):
    """Plot sensory and motor layer dynamics for a specific target."""
    sensory_activity = np.array(target_results[target_idx]["sensory_activity"])
    motor_activity = np.array(target_results[target_idx]["motor_activity"])
    time_steps = range(sensory_activity.shape[0])

    fig, ax = plt.subplots(figsize=(8, 4))
    ax.plot(time_steps, np.mean(sensory_activity, axis=1), label="Sensory Layer (y_s)", color="blue")
    ax.plot(time_steps, np.mean(motor_activity, axis=1), label="Motor Layer (y_m)", color="green")

    ax.set_title(f"Neural Dynamics (Target {target_idx + 1})")
    ax.set_xlabel("Time steps")
    ax.set_ylabel("Average Activity")
    ax.legend()
    ax.grid()
    plt.tight_layout()
    plt.show()

# plot_neural_dynamics(target_results, target_idx=0)

# %% [markdown]
# ---

# %%
def plot_reflex_gain(target_results):
    """Plot reflex gain modulation over time for all targets."""
    fig, ax = plt.subplots(figsize=(8, 4))
    for target_idx, target_data in target_results.items():
        # Flatten the list of lists into a single list
        reflex_gain = [gain for epoch in target_data["reflex_gain"] for gain in epoch]
        time_steps = range(len(reflex_gain))
        ax.plot(time_steps, reflex_gain, label=f"Target {target_idx + 1}")

    ax.set_title("Reflex Gain Modulation Over Time")
    ax.set_xlabel("Time steps")
    ax.set_ylabel("Reflex Gain (G_s)")
    ax.legend()
    ax.grid()
    plt.tight_layout()
    plt.show()

# plot_reflex_gain(target_results)

# %% [markdown]
# ---

# %%
def plot_cost_trends(target_results):
    """Plot cost component trends over epochs."""
    cost_keys = ["neural", "force", "kinematic"]
    fig, ax = plt.subplots(figsize=(8, 4))

    for key in cost_keys:
        avg_costs = []
        for target_idx in target_results:
            # Check if the cost list is not empty
            if target_results[target_idx]["costs"][key]:
                avg_costs.append(np.mean(target_results[target_idx]["costs"][key]))
            else:
                avg_costs.append(np.nan)  # Use NaN for missing data

        ax.plot(range(len(avg_costs)), avg_costs, label=f"{key.capitalize()} Cost")

    ax.set_title("Cost Component Trends Over Epochs")
    ax.set_xlabel("Epochs")
    ax.set_ylabel("Cost")
    ax.legend()
    ax.grid()
    plt.tight_layout()
    plt.show()

# plot_cost_trends(target_results)

# %% [markdown]
# ---

# %%
def plot_pose_error_vs_reward(target_results):
    """Plot pose error vs. reward for all targets."""
    fig, ax = plt.subplots(figsize=(8, 4))
    for target_idx, target_data in target_results.items():
        # Flatten pose errors and rewards
        pose_errors = [error for epoch in target_data["pose_errors"] for error in epoch]
        rewards = [reward for epoch in target_data["rewards"] for reward in epoch]

        # Ensure lengths match before plotting
        if len(pose_errors) == len(rewards):
            ax.plot(pose_errors, rewards, label=f"Target {target_idx + 1}")
        else:
            print(f"Skipping target {target_idx + 1} due to mismatched lengths.")

    ax.set_title("Pose Error vs. Reward")
    ax.set_xlabel("Pose Error")
    ax.set_ylabel("Reward")
    ax.legend()
    ax.grid()
    plt.tight_layout()
    plt.show()

# plot_pose_error_vs_reward(target_results)

# %% [markdown]
# ---
